# %% [markdown]
# # Introduction to using ParticleSpy

# %% [markdown]
# This is an example notebook for performing particle analysis using ParticleSpy.
#
# This notebook takes a HAADF image of nanoparticles, allows the user to determine the best segmentation method and then performs analysis, producing a plot of particle areas.

# %% [markdown]
# Below, we load an image using Hyperspy.

# %%
import hyperspy.api as hs
import particlespy.api as ps
import trackpy as tp
import matplotlib.pyplot as plt

filename = 'SiO2 HAADF Image.hspy'
haadf = hs.load(filename)

# %matplotlib inline
haadf.plot()
# Out:
# C:\Users\Tom Slater\anaconda3\envs\particlespy_270423\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\Tom Slater\anaconda3\envs\particlespy_270423\lib\site-packages\hyperspy\misc\utils.py:471: VisibleDeprecationWarning: Use of the `binned` attribute in metadata is going to be deprecated in v2.0. Set the `axis.is_binned` attribute instead.
#   warnings.warn(
# C:\Users\Tom Slater\anaconda3\envs\particlespy_270423\lib\site-packages\hyperspy\io.py:572: VisibleDeprecationWarning: Loading old file version. The binned attribute has been moved from metadata.Signal to axis.is_binned. Setting this attribute for all signal axes instead.
#   warnings.warn('Loading old file version. The binned attribute '

# %% [markdown]
# ParticleSpy works by defining parameters to run segmentation. This is done through the parameters object, which can be loaded with default values.

# %%
params = ps.parameters()
params.generate()

# %% [markdown]
# Let's take a look at the default segmentation parameters.

# %%
params.segment
# Out:
# {'threshold': 'otsu',
#  'watershed': False,
#  'watershed_size': 0,
#  'watershed_erosion': 0,
#  'invert': False,
#  'min_size': 0,
#  'rb_kernel': 0,
#  'gaussian': 0,
#  'local_size': 1}

# %% [markdown]
# The default is a simple Otsu threshold with no other options selected. We could apply these parameters to segment the particles but we don't know how well these will work on our individual images. In order to check this out, we can use ParticleSpy's segmentation GUI. Experiment with changing the threshold algorithm and the application of watershedding to obtain the optimum labels. Once happy, click "Get Params" to print the current parameters.
#
# <span style="color:red">WARNING: Don't run this if on Google Cloud Platform!</span>

# %%
ps.seg_ui(haadf)
# Out:
# {'threshold': 'otsu', 'watershed': True, 'watershed_size': 5, 'watershed_erosion': 0, 'invert': False, 'min_size': 0, 'rb_kernel': 0, 'gaussian': 0, 'local_size': 1}

# %% [markdown]
# Next, we use the parameters saved when last pressing Update in the GUI to construct a parameter dictionary.

# %%
params.load()
params.store['store_im'] = True

# %%
params.segment
# Out:
# {'threshold': 'otsu',
#  'watershed': True,
#  'watershed_size': 5,
#  'watershed_erosion': 0,
#  'invert': False,
#  'min_size': 0,
#  'rb_kernel': 0,
#  'gaussian': 0,
#  'local_size': 1}

# %% [markdown]
# If running a notebook on a remote server there is an alternative method to check segmentation parameters using the process function (however, this isn't included in the api).

# %%
import particlespy
seg = particlespy.segptcls.process(haadf,params)
plt.figure()
plt.imshow(seg)

# %% [markdown]
# Once we're happy with the segmentation parameters, we run the particle_analysis function to segment our image and provide a list of all the particles.

# %%
particles = ps.particle_analysis(haadf,params)
# Out:
# c:\users\tom slater\onedrive - cardiff university\documents\github\particlespy\particlespy\particle_analysis.py:111: RuntimeWarning: divide by zero encountered in double_scalars
#   circularity = 4*3.14159265*p.properties['area']['value']/(peri**2)

# %% [markdown]
# Let's interrogate the particle data a little bit. From an initial image we get a number of particle properties calculated automatically.

# %%
particles.list
# Out:
# [<particlespy.ptcl_class.particle at 0x1cc0e4b2470>,
#  <particlespy.ptcl_class.particle at 0x1cc0e4b25f0>,
#  <particlespy.ptcl_class.particle at 0x1cc0ecb5330>,
#  <particlespy.ptcl_class.particle at 0x1cc0ecfb820>,
#  <particlespy.ptcl_class.particle at 0x1cc0ecfb8b0>,
#  <particlespy.ptcl_class.particle at 0x1cc0eb02b90>,
#  <particlespy.ptcl_class.particle at 0x1cc0eb41ea0>,
#  <particlespy.ptcl_class.particle at 0x1cc0eb71180>,
#  <particlespy.ptcl_class.particle at 0x1cc0ebb7d60>,
#  <particlespy.ptcl_class.particle at 0x1cc0ebb7df0>,
#  <particlespy.ptcl_class.particle at 0x1cc0ed3f610>,
#  <particlespy.ptcl_class.particle at 0x1cc0ed7ae60>,
#  <particlespy.ptcl_class.particle at 0x1cc0edb2680>,
#  <particlespy.ptcl_class.particle at 0x1cc0ede1ea0>,
#  <particlespy.ptcl_class.particle at 0x1cc0ee1d6c0>,
#  <particlespy.ptcl_class.particle at 0x1cc0ee4cee0>,
#  <particlespy.ptcl_class.particle at 0x1cc0ee93e80>,
#  <particlespy.ptcl_class.particle at 0x1cc0ee93e50>,
#  <particlespy.ptcl_class.particle at 0x1cc0eecf730>,
#  <particlespy.ptcl_class.particle at 0x1cc0ef0af50>,
#  <particlespy.ptcl_class.particle at 0x1cc0ef46770>,
#  <particlespy.ptcl_class.particle at 0x1cc0ef75f90>,
#  <particlespy.ptcl_class.particle at 0x1cc0efb17b0>,
#  <particlespy.ptcl_class.particle at 0x1cc0efd8eb0>,
#  <particlespy.ptcl_class.particle at 0x1cc0f02bf70>,
#  <particlespy.ptcl_class.particle at 0x1cc0f02bf40>,
#  <particlespy.ptcl_class.particle at 0x1cc0f06b820>,
#  <particlespy.ptcl_class.particle at 0x1cc0f0a7040>,
#  <particlespy.ptcl_class.particle at 0x1cc0f0ea860>,
#  <particlespy.ptcl_class.particle at 0x1cc0f116080>,
#  <particlespy.ptcl_class.particle at 0x1cc0f1518a0>,
#  <particlespy.ptcl_class.particle at 0x1cc0f1850c0>,
#  <particlespy.ptcl_class.particle at 0x1cc0f1c3fa0>,
#  <particlespy.ptcl_class.particle at 0x1cc0f1c08e0>,
#  <particlespy.ptcl_class.particle at 0x1cc0f20f8e0>,
#  <particlespy.ptcl_class.particle at 0x1cc11b23100>,
#  <particlespy.ptcl_class.particle at 0x1cc11b62920>,
#  <particlespy.ptcl_class.particle at 0x1cc11b9a140>,
#  <particlespy.ptcl_class.particle at 0x1cc11bd1960>,
#  <particlespy.ptcl_class.particle at 0x1cc11c05180>,
#  <particlespy.ptcl_class.particle at 0x1cc11c3c9a0>,
#  <particlespy.ptcl_class.particle at 0x1cc11c7f8e0>,
#  <particlespy.ptcl_class.particle at 0x1cc11c7f970>,
#  <particlespy.ptcl_class.particle at 0x1cc11cbb190>,
#  <particlespy.ptcl_class.particle at 0x1cc11cfa9b0>,
#  <particlespy.ptcl_class.particle at 0x1cc11d2e1d0>,
#  <particlespy.ptcl_class.particle at 0x1cc11d699f0>,
#  <particlespy.ptcl_class.particle at 0x1cc11d9d210>,
#  <particlespy.ptcl_class.particle at 0x1cc11dd8a30>,
#  <particlespy.ptcl_class.particle at 0x1cc11e1b9a0>,
#  <particlespy.ptcl_class.particle at 0x1cc11e1ba30>,
#  <particlespy.ptcl_class.particle at 0x1cc11e53250>,
#  <particlespy.ptcl_class.particle at 0x1cc11e8aa70>,
#  <particlespy.ptcl_class.particle at 0x1cc11ec2290>,
#  <particlespy.ptcl_class.particle at 0x1cc11ef9ab0>,
#  <particlespy.ptcl_class.particle at 0x1cc11fd92d0>,
#  <particlespy.ptcl_class.particle at 0x1cc12010af0>,
#  <particlespy.ptcl_class.particle at 0x1cc1205faf0>,
#  <particlespy.ptcl_class.particle at 0x1cc1205fb80>,
#  <particlespy.ptcl_class.particle at 0x1cc120973a0>,
#  <particlespy.ptcl_class.particle at 0x1cc120d6bc0>,
#  <particlespy.ptcl_class.particle at 0x1cc121063e0>,
#  <particlespy.ptcl_class.particle at 0x1cc1214dc00>,
#  <particlespy.ptcl_class.particle at 0x1cc12175420>,
#  <particlespy.ptcl_class.particle at 0x1cc121b4c40>,
#  <particlespy.ptcl_class.particle at 0x1cc1309fbb0>,
#  <particlespy.ptcl_class.particle at 0x1cc1309fc40>,
#  <particlespy.ptcl_class.particle at 0x1cc130e3460>,
#  <particlespy.ptcl_class.particle at 0x1cc1311ec80>,
#  <particlespy.ptcl_class.particle at 0x1cc1314a4a0>,
#  <particlespy.ptcl_class.particle at 0x1cc0df85840>,
#  <particlespy.ptcl_class.particle at 0x1cc131c3b80>,
#  <particlespy.ptcl_class.particle at 0x1cc131c3c10>,
#  <particlespy.ptcl_class.particle at 0x1cc131e7430>,
#  <particlespy.ptcl_class.particle at 0x1cc13236c50>,
#  <particlespy.ptcl_class.particle at 0x1cc1326e470>,
#  <particlespy.ptcl_class.particle at 0x1cc0e011c90>,
#  <particlespy.ptcl_class.particle at 0x1cc0e04d4b0>,
#  <particlespy.ptcl_class.particle at 0x1cc0e084cd0>,
#  <particlespy.ptcl_class.particle at 0x1cc0e0c3c40>,
#  <particlespy.ptcl_class.particle at 0x1cc0e0c3cd0>,
#  <particlespy.ptcl_class.particle at 0x1cc132974f0>,
#  <particlespy.ptcl_class.particle at 0x1cc132cad10>,
#  <particlespy.ptcl_class.particle at 0x1cc1330e530>,
#  <particlespy.ptcl_class.particle at 0x1cc13339d50>,
#  <particlespy.ptcl_class.particle at 0x1cc13371570>,
#  <particlespy.ptcl_class.particle at 0x1cc133a0d90>,
#  <particlespy.ptcl_class.particle at 0x1cc133ebd00>,
#  <particlespy.ptcl_class.particle at 0x1cc133ebd90>,
#  <particlespy.ptcl_class.particle at 0x1cc134275b0>,
#  <particlespy.ptcl_class.particle at 0x1cc1346add0>,
#  <particlespy.ptcl_class.particle at 0x1cc134a25f0>,
#  <particlespy.ptcl_class.particle at 0x1cc134d9e10>,
#  <particlespy.ptcl_class.particle at 0x1cc13511630>,
#  <particlespy.ptcl_class.particle at 0x1cc13544e50>,
#  <particlespy.ptcl_class.particle at 0x1cc1358bdc0>,
#  <particlespy.ptcl_class.particle at 0x1cc1358be50>,
#  <particlespy.ptcl_class.particle at 0x1cc135cb670>,
#  <particlespy.ptcl_class.particle at 0x1cc1360ae90>,
#  <particlespy.ptcl_class.particle at 0x1cc136426b0>,
#  <particlespy.ptcl_class.particle at 0x1cc13672020>,
#  <particlespy.ptcl_class.particle at 0x1cc136a9720>,
#  <particlespy.ptcl_class.particle at 0x1cc136d4f40>,
#  <particlespy.ptcl_class.particle at 0x1cc13723ee0>,
#  <particlespy.ptcl_class.particle at 0x1cc13723eb0>,
#  <particlespy.ptcl_class.particle at 0x1cc1375b790>,
#  <particlespy.ptcl_class.particle at 0x1cc1476afb0>,
#  <particlespy.ptcl_class.particle at 0x1cc147a27d0>,
#  <particlespy.ptcl_class.particle at 0x1cc147e5ff0>,
#  <particlespy.ptcl_class.particle at 0x1cc14811810>,
#  <particlespy.ptcl_class.particle at 0x1cc14849030>,
#  <particlespy.ptcl_class.particle at 0x1cc1487ffa0>,
#  <particlespy.ptcl_class.particle at 0x1cc1487ff70>,
#  <particlespy.ptcl_class.particle at 0x1cc148cb850>,
#  <particlespy.ptcl_class.particle at 0x1cc14903070>,
#  <particlespy.ptcl_class.particle at 0x1cc14936890>,
#  <particlespy.ptcl_class.particle at 0x1cc1496e0b0>,
#  <particlespy.ptcl_class.particle at 0x1cc1499d8d0>,
#  <particlespy.ptcl_class.particle at 0x1cc149e10f0>,
#  <particlespy.ptcl_class.particle at 0x1cc14a1bfd0>,
#  <particlespy.ptcl_class.particle at 0x1cc14a1bf70>,
#  <particlespy.ptcl_class.particle at 0x1cc14a5f910>,
#  <particlespy.ptcl_class.particle at 0x1cc14a9b130>,
#  <particlespy.ptcl_class.particle at 0x1cc14ada950>,
#  <particlespy.ptcl_class.particle at 0x1cc14b06170>,
#  <particlespy.ptcl_class.particle at 0x1cc14b39990>,
#  <particlespy.ptcl_class.particle at 0x1cc14b791b0>,
#  <particlespy.ptcl_class.particle at 0x1cc14bac9d0>,
#  <particlespy.ptcl_class.particle at 0x1cc14bf7940>,
#  <particlespy.ptcl_class.particle at 0x1cc14bf79d0>,
#  <particlespy.ptcl_class.particle at 0x1cc14c331f0>,
#  <particlespy.ptcl_class.particle at 0x1cc14c66a10>,
#  <particlespy.ptcl_class.particle at 0x1cc14ca6230>,
#  <particlespy.ptcl_class.particle at 0x1cc14cd1a50>,
#  <particlespy.ptcl_class.particle at 0x1cc14d09270>,
#  <particlespy.ptcl_class.particle at 0x1cc14d44a90>,
#  <particlespy.ptcl_class.particle at 0x1cc14d8ba30>,
#  <particlespy.ptcl_class.particle at 0x1cc14d8bac0>,
#  <particlespy.ptcl_class.particle at 0x1cc14dcf2e0>,
#  <particlespy.ptcl_class.particle at 0x1cc14dfeb00>,
#  <particlespy.ptcl_class.particle at 0x1cc14e32320>,
#  <particlespy.ptcl_class.particle at 0x1cc14e71b40>,
#  <particlespy.ptcl_class.particle at 0x1cc14e9d360>,
#  <particlespy.ptcl_class.particle at 0x1cc14ed8b80>,
#  <particlespy.ptcl_class.particle at 0x1cc14f1baf0>,
#  <particlespy.ptcl_class.particle at 0x1cc14f1bb80>,
#  <particlespy.ptcl_class.particle at 0x1cc14f5b3d0>,
#  <particlespy.ptcl_class.particle at 0x1cc14f8ec20>,
#  <particlespy.ptcl_class.particle at 0x1cc14fca440>,
#  <particlespy.ptcl_class.particle at 0x1cc15005c60>,
#  <particlespy.ptcl_class.particle at 0x1cc1502d480>,
#  <particlespy.ptcl_class.particle at 0x1cc15074ca0>,
#  <particlespy.ptcl_class.particle at 0x1cc150b7c10>,
#  <particlespy.ptcl_class.particle at 0x1cc150b7ca0>,
#  <particlespy.ptcl_class.particle at 0x1cc150f74c0>,
#  <particlespy.ptcl_class.particle at 0x1cc1512ace0>,
#  <particlespy.ptcl_class.particle at 0x1cc15162500>,
#  <particlespy.ptcl_class.particle at 0x1cc15195d20>,
#  <particlespy.ptcl_class.particle at 0x1cc151cd540>,
#  <particlespy.ptcl_class.particle at 0x1cc15204d60>,
#  <particlespy.ptcl_class.particle at 0x1cc1524bcd0>,
#  <particlespy.ptcl_class.particle at 0x1cc1524bd60>,
#  <particlespy.ptcl_class.particle at 0x1cc1528f580>,
#  <particlespy.ptcl_class.particle at 0x1cc152c2da0>,
#  <particlespy.ptcl_class.particle at 0x1cc152f65c0>,
#  <particlespy.ptcl_class.particle at 0x1cc15329de0>,
#  <particlespy.ptcl_class.particle at 0x1cc15369600>,
#  <particlespy.ptcl_class.particle at 0x1cc15394e20>,
#  <particlespy.ptcl_class.particle at 0x1cc153dfd90>,
#  <particlespy.ptcl_class.particle at 0x1cc153dfe20>,
#  <particlespy.ptcl_class.particle at 0x1cc15417640>,
#  <particlespy.ptcl_class.particle at 0x1cc1545ae90>,
#  <particlespy.ptcl_class.particle at 0x1cc154926b0>,
#  <particlespy.ptcl_class.particle at 0x1cc154c1ed0>,
#  <particlespy.ptcl_class.particle at 0x1cc154f96f0>,
#  <particlespy.ptcl_class.particle at 0x1cc15530f10>,
#  <particlespy.ptcl_class.particle at 0x1cc15577e80>,
#  <particlespy.ptcl_class.particle at 0x1cc15577e50>,
#  <particlespy.ptcl_class.particle at 0x1cc155bb730>,
#  <particlespy.ptcl_class.particle at 0x1cc155eef50>,
#  <particlespy.ptcl_class.particle at 0x1cc15632770>,
#  <particlespy.ptcl_class.particle at 0x1cc1566df90>,
#  <particlespy.ptcl_class.particle at 0x1cc156a17b0>,
#  <particlespy.ptcl_class.particle at 0x1cc156d0fd0>,
#  <particlespy.ptcl_class.particle at 0x1cc1570ff40>,
#  <particlespy.ptcl_class.particle at 0x1cc1570ff10>,
#  <particlespy.ptcl_class.particle at 0x1cc157537f0>,
#  <particlespy.ptcl_class.particle at 0x1cc15797010>,
#  <particlespy.ptcl_class.particle at 0x1cc157c6830>,
#  <particlespy.ptcl_class.particle at 0x1cc15802050>,
#  <particlespy.ptcl_class.particle at 0x1cc15835870>,
#  <particlespy.ptcl_class.particle at 0x1cc15871090>,
#  <particlespy.ptcl_class.particle at 0x1cc158a7fd0>,
#  <particlespy.ptcl_class.particle at 0x1cc158a7fa0>,
#  <particlespy.ptcl_class.particle at 0x1cc158eb8b0>,
#  <particlespy.ptcl_class.particle at 0x1cc159170d0>,
#  <particlespy.ptcl_class.particle at 0x1cc1595e8f0>,
#  <particlespy.ptcl_class.particle at 0x1cc15996110>]

# %%
print(particles.list[0].properties)
# Out:
# {'area': {'value': 0.0013897423288512954, 'units': 'µm^2'}, 'equivalent circular diameter': {'value': 0.042065126768925924, 'units': 'µm'}, 'x': {'value': 0.04861390374993023, 'units': 'µm'}, 'y': {'value': 0.839490097163147, 'units': 'µm'}, 'major axis length': {'value': 0.04343684018581211, 'units': 'µm'}, 'minor axis length': {'value': 0.04152910281239791, 'units': 'µm'}, 'circularity': {'value': 1.2801536991122482, 'units': None}, 'eccentricity': {'value': 0.2931051908802741, 'units': None}, 'solidity': {'value': 0.95, 'units': None}, 'intensity': {'value': 9467681.0, 'units': None}, 'intensity_max': {'value': 738979.7, 'units': None}, 'intensity_std': {'value': 0.023866808, 'units': None}, 'bbox_area': {'value': 0.001828608327435915, 'units': 'µm^2'}, 'bbox_length': {'value': 0.06047492583601761, 'units': 'µm'}, 'frame': {'value': None, 'units': None}}

# %% [markdown]
# It is then possible to plot a histogram of particle area.

# %%
particles.plot('eccentricity',bins=20)

# %% [markdown]
# It is also possible to plot a scatter plot of two properties. In this instance, plotting 'intensity' vs area.

# %%
particles.plot(['intensity','area','eccentricity'])

# %% [markdown]
# ## ParticleSpy with EDS data

# %% [markdown]
# If you have EDS data collected simultaneously with an image, it is possible to extract maps, spectra and the composition from each segmented particle. Firstly, load the EDS spectrum image.

# %%
eds_filename = 'SiO2 EDS Spectrum Image.hspy'
eds = hs.load(eds_filename)
# Out:
# C:\Users\Tom Slater\anaconda3\envs\particlespy_270423\lib\site-packages\hyperspy\misc\utils.py:471: VisibleDeprecationWarning: Use of the `binned` attribute in metadata is going to be deprecated in v2.0. Set the `axis.is_binned` attribute instead.
#   warnings.warn(
# C:\Users\Tom Slater\anaconda3\envs\particlespy_270423\lib\site-packages\hyperspy\io.py:572: VisibleDeprecationWarning: Loading old file version. The binned attribute has been moved from metadata.Signal to axis.is_binned. Setting this attribute for all signal axes instead.
#   warnings.warn('Loading old file version. The binned attribute '

# %% [markdown]
# Next, put the HAADF image and EDS spectrum image together in a list to make one acquisition.

# %%
ac = [haadf.isig[0:32,0:32],eds.inav[0:32,0:32]]

# %% [markdown]
# At this point, we need to set the parameters for the EDS analysis. This can be done by taking our previously used parameters object adding parameters with generate_eds().

# %%
params.generate_eds(eds_method='CL',elements=['Si','O'],factors=[1.1,1.3],store_maps=True)

# %% [markdown]
# Now, we need to run ParticleAnalysis again in order to get the accompanying EDS data.

# %%
particles2 = ps.particle_analysis(ac,params)
# Out:
# [########################################] | 100% Completed | 117.78 ms
# [########################################] | 100% Completed | 113.63 ms
# [########################################] | 100% Completed | 109.85 ms
# [########################################] | 100% Completed | 117.56 ms
# [########################################] | 100% Completed | 107.33 ms
# [########################################] | 100% Completed | 103.11 ms
# [########################################] | 100% Completed | 105.56 ms
# c:\users\tom slater\onedrive - cardiff university\documents\github\particlespy\particlespy\particle_analysis.py:111: RuntimeWarning: divide by zero encountered in double_scalars
#   circularity = 4*3.14159265*p.properties['area']['value']/(peri**2)
# [########################################] | 100% Completed | 104.49 ms
# [########################################] | 100% Completed | 109.49 ms
# [########################################] | 100% Completed | 116.00 ms
# [########################################] | 100% Completed | 108.59 ms

# %% [markdown]
# The extracted maps of each element can be accessed from the particle list from maps['element'].

# %%
particles2.list[1].maps['O'].plot()

# %% [markdown]
# The composition of each particle can be accessed from the particle list using list[particle].composition.

# %%
particles2.list[1].composition
# Out:
# {'O': array([46.6682614]), 'Si': array([53.3317386])}

# %% [markdown]
# We can plot a radial profile of the particle intensity from both the image and our elemental maps.

# %%
rp = ps.radial_profile(particles2.list[1],['Image'],plot=True)

# %%
rp2 = ps.radial_profile(particles2.list[1],['Si','O'],plot=True)

# %% [markdown]
# ## ParticleSpy with time-series data

# %% [markdown]
# ParticleSpy can also be used to track properties through a time-series of images. Let's see that in action on a short series of only 10 frames.

# %%
series = hs.load('particle_series.dm4')

# %%
# %matplotlib qt

# %%
series.plot()

# %% [markdown]
# We'll define some new parameters that work well for this data.

# %%
params_series = ps.parameters()

# %%
params_series.generate(threshold='mean',min_size=200,gaussian=3)

# %% [markdown]
# For particle series, there is a modified ParticleAnalysis function called ParticleAnalysisSeries that deals with multiple frames.

# %%
particles_series = ps.particle_analysis_series(series, params_series)

# %%
particles_series.list[100].properties
# Out:
# {'area': {'value': 0.37706123399901337, 'units': 'nm^2'},
#  'equivalent circular diameter': {'value': 0.6928847479301176, 'units': 'nm'},
#  'x': {'value': 16.174399685484072, 'units': 'nm'},
#  'y': {'value': 6.241437284091163, 'units': 'nm'},
#  'major axis length': {'value': 1.0308994115209218, 'units': 'nm'},
#  'minor axis length': {'value': 0.5138510562901347, 'units': 'nm'},
#  'circularity': {'value': 0.6635403418626301, 'units': None},
#  'eccentricity': {'value': 0.8669188704654908, 'units': None},
#  'solidity': {'value': 0.8642857142857143, 'units': None},
#  'intensity': {'value': 12842862.0, 'units': None},
#  'intensity_max': {'value': 354781.34, 'units': None},
#  'intensity_std': {'value': 0.007392826, 'units': None},
#  'bbox_area': {'value': 0.6808915671800366, 'units': 'nm^2'},
#  'bbox_length': {'value': 1.177587704896601, 'units': 'nm'},
#  'frame': {'value': 3, 'units': None}}

# %% [markdown]
# Now we have a list of particles, with their properties attached including the frame number. We can now pass them through another function that uses the trackpy package to track the same particles through a time series.

# %%
series_test = ps.time_series_analysis(particles_series)
# Out:
# Frame 9: 25 trajectories present.

# %% [markdown]
# The returned series_test is a pandas dataframe, which is the standard object that is used in trackpy.

# %% [markdown]
# We can use trackpy to do cool things like plot the trajectory of all particles in the series. Note: while the axes say they are in pixels, they are actually in nm in this case! (I have just noticed this and will fix)

# %%
plt.figure()
tp.plot_traj(series_test)
# Out:
# <Axes: xlabel='x [px]', ylabel='y [px]'>

# %% [markdown]
# Trackpy also lets you correct for any systematic drift in the series.

# %%
drift = tp.compute_drift(series_test)
drift.plot()
# Out:
# <Axes: xlabel='frame'>

# %%
tm = tp.subtract_drift(series_test.copy(), drift)
plt.figure()
tp.plot_traj(tm)
# Out:
# <Axes: xlabel='x [px]', ylabel='y [px]'>

# %% [markdown]
# Using the particlespy workflow for time-series data, you also have any of the properties specified in the pandas dataframe and you can plot these as a function of frame number.

# %%
import matplotlib.pyplot as plt
plt.figure()
for index, particle in tm.groupby('particle'):
    plt.plot(particle['frame'], particle['area'], label=index)
    plt.xlabel('Frame')
    plt.ylabel('Area (nm)')
